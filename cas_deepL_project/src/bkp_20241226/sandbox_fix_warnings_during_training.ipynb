# %%
import numpy as np
import os

def process_masks_to_npy(input_path, output_path, chunk_size=1000):
    """
    Process masks to binary format in smaller chunks and save in standard .npy format.
    
    Parameters:
    - input_path: Path to the input mask file
    - output_path: Path to save the processed mask file
    - chunk_size: Number of slices to process at a time
    """
    try:
        # Load input masks in memory-mapped mode
        masks = np.load(input_path, mmap_mode="r")
        num_slices = masks.shape[0]
        print(f"Loaded masks: {masks.shape}")

        # Process in chunks
        binary_masks = np.zeros_like(masks, dtype="int8")  # Prepare an output array
        for start_idx in range(0, num_slices, chunk_size):
            end_idx = min(start_idx + chunk_size, num_slices)
            chunk = masks[start_idx:end_idx]  # Load a chunk
            binary_masks[start_idx:end_idx] = np.where(chunk > 0, 1, 0)  # Convert to binary
            print(f"Processed slices {start_idx} to {end_idx - 1}")

        # Save the processed binary masks as a standard .npy file
        np.save(output_path, binary_masks)
        print(f"Binary masks saved successfully to {output_path}")

        # Validate the saved file
        cleaned_masks = np.load(output_path)
        print(f"Validation - Shape of cleaned masks: {cleaned_masks.shape}")
        print(f"Validation - Unique values in cleaned masks: {np.unique(cleaned_masks)}")
    
    except Exception as e:
        print(f"Error during processing: {e}")

# Define paths
mask_path = "../data/training_data/val/Residential_val_masks_combined.npy"
output_path = "../data/training_data/val/Residential_val_masks_cleaned.npy"

# Process the masks
process_masks_to_npy(mask_path, output_path)
# Out:
# Loaded masks: (123360, 257, 21)
# Processed slices 0 to 999
# Processed slices 1000 to 1999
# Processed slices 2000 to 2999
# Processed slices 3000 to 3999
# Processed slices 4000 to 4999
# Processed slices 5000 to 5999
# Processed slices 6000 to 6999
# Processed slices 7000 to 7999
# Processed slices 8000 to 8999
# Processed slices 9000 to 9999
# Processed slices 10000 to 10999
# Processed slices 11000 to 11999
# Processed slices 12000 to 12999
# Processed slices 13000 to 13999
# Processed slices 14000 to 14999
# Processed slices 15000 to 15999
# Processed slices 16000 to 16999
# Processed slices 17000 to 17999
# Processed slices 18000 to 18999
# Processed slices 19000 to 19999
# Processed slices 20000 to 20999
# Processed slices 21000 to 21999
# Processed slices 22000 to 22999
# Processed slices 23000 to 23999
# Processed slices 24000 to 24999
# Processed slices 25000 to 25999
# Processed slices 26000 to 26999
# Processed slices 27000 to 27999
# Processed slices 28000 to 28999
# Processed slices 29000 to 29999
# Processed slices 30000 to 30999
# Processed slices 31000 to 31999
# Processed slices 32000 to 32999
# Processed slices 33000 to 33999
# Processed slices 34000 to 34999
# Processed slices 35000 to 35999
# Processed slices 36000 to 36999
# Processed slices 37000 to 37999
# Processed slices 38000 to 38999
# Processed slices 39000 to 39999
# Processed slices 40000 to 40999
# Processed slices 41000 to 41999
# Processed slices 42000 to 42999
# Processed slices 43000 to 43999
# Processed slices 44000 to 44999
# Processed slices 45000 to 45999
# Processed slices 46000 to 46999
# Processed slices 47000 to 47999
# Processed slices 48000 to 48999
# Processed slices 49000 to 49999
# Processed slices 50000 to 50999
# Processed slices 51000 to 51999
# Processed slices 52000 to 52999
# Processed slices 53000 to 53999
# Processed slices 54000 to 54999
# Processed slices 55000 to 55999
# Processed slices 56000 to 56999
# Processed slices 57000 to 57999
# Processed slices 58000 to 58999
# Processed slices 59000 to 59999
# Processed slices 60000 to 60999
# Processed slices 61000 to 61999
# Processed slices 62000 to 62999
# Processed slices 63000 to 63999
# Processed slices 64000 to 64999
# Processed slices 65000 to 65999
# Processed slices 66000 to 66999
# Processed slices 67000 to 67999
# Processed slices 68000 to 68999
# Processed slices 69000 to 69999
# Processed slices 70000 to 70999
# Processed slices 71000 to 71999
# Processed slices 72000 to 72999
# Processed slices 73000 to 73999
# Processed slices 74000 to 74999
# Processed slices 75000 to 75999
# Processed slices 76000 to 76999
# Processed slices 77000 to 77999
# Processed slices 78000 to 78999
# Processed slices 79000 to 79999
# Processed slices 80000 to 80999
# Processed slices 81000 to 81999
# Processed slices 82000 to 82999
# Processed slices 83000 to 83999
# Processed slices 84000 to 84999
# Processed slices 85000 to 85999
# Processed slices 86000 to 86999
# Processed slices 87000 to 87999
# Processed slices 88000 to 88999
# Processed slices 89000 to 89999
# Processed slices 90000 to 90999
# Processed slices 91000 to 91999
# Processed slices 92000 to 92999
# Processed slices 93000 to 93999
# Processed slices 94000 to 94999
# Processed slices 95000 to 95999
# Processed slices 96000 to 96999
# Processed slices 97000 to 97999
# Processed slices 98000 to 98999
# Processed slices 99000 to 99999
# Processed slices 100000 to 100999
# Processed slices 101000 to 101999
# Processed slices 102000 to 102999
# Processed slices 103000 to 103999
# Processed slices 104000 to 104999
# Processed slices 105000 to 105999
# Processed slices 106000 to 106999
# Processed slices 107000 to 107999
# Processed slices 108000 to 108999
# Processed slices 109000 to 109999
# Processed slices 110000 to 110999
# Processed slices 111000 to 111999
# Processed slices 112000 to 112999
# Processed slices 113000 to 113999
# Processed slices 114000 to 114999
# Processed slices 115000 to 115999
# Processed slices 116000 to 116999
# Processed slices 117000 to 117999
# Processed slices 118000 to 118999
# Processed slices 119000 to 119999
# Processed slices 120000 to 120999
# Processed slices 121000 to 121999
# Processed slices 122000 to 122999
# Processed slices 123000 to 123359
# Binary masks saved successfully to ../data/training_data/val/Residential_val_masks_cleaned.npy
# Validation - Shape of cleaned masks: (123360, 257, 21)
# Validation - Unique values in cleaned masks: [0 1]

# %%
import numpy as np
import cv2

# Paths
input_cleaned_masks = "../data/training_data/train/AnnualCrop_train_masks_cleaned.npy"
output_resized_masks = "../data/training_data/train/AnnualCrop_train_masks_cleaned_resized.npy"

# Load cleaned masks in memory-mapped mode
cleaned_masks = np.load(input_cleaned_masks, mmap_mode="r")

# Open a memory-mapped file for the output
num_samples = cleaned_masks.shape[0]
output_shape = (num_samples, 512, 512)
resized_masks = np.memmap(output_resized_masks, dtype="int8", mode="w+", shape=output_shape)

chunk_size = 1000  # Adjust chunk size based on memory availability

# Process masks in chunks
for start_idx in range(0, num_samples, chunk_size):
    end_idx = min(start_idx + chunk_size, num_samples)
    chunk = cleaned_masks[start_idx:end_idx]
    
    # Resize each mask in the chunk
    for i, mask in enumerate(chunk):
        resized_masks[start_idx + i] = cv2.resize(mask, (512, 512), interpolation=cv2.INTER_NEAREST)
    
    print(f"Processed and saved masks from index {start_idx} to {end_idx - 1}")

# Ensure changes are written to disk
resized_masks.flush()
print(f"Resized masks saved to {output_resized_masks}")
# Out:
# Processed and saved masks from index 0 to 999
# Processed and saved masks from index 1000 to 1999
# Processed and saved masks from index 2000 to 2999
# Processed and saved masks from index 3000 to 3999
# Processed and saved masks from index 4000 to 4999
# Processed and saved masks from index 5000 to 5999
# Processed and saved masks from index 6000 to 6999
# Processed and saved masks from index 7000 to 7999
# Processed and saved masks from index 8000 to 8999
# Processed and saved masks from index 9000 to 9999
# Processed and saved masks from index 10000 to 10999
# Processed and saved masks from index 11000 to 11999
# Processed and saved masks from index 12000 to 12999
# Processed and saved masks from index 13000 to 13999
# Processed and saved masks from index 14000 to 14999
# Processed and saved masks from index 15000 to 15999
# Processed and saved masks from index 16000 to 16999
# Processed and saved masks from index 17000 to 17999
# Processed and saved masks from index 18000 to 18999
# Processed and saved masks from index 19000 to 19999
# Processed and saved masks from index 20000 to 20999
# Processed and saved masks from index 21000 to 21999
# Processed and saved masks from index 22000 to 22999
# Processed and saved masks from index 23000 to 23999
# Processed and saved masks from index 24000 to 24999
# Processed and saved masks from index 25000 to 25999
# Processed and saved masks from index 26000 to 26999
# Processed and saved masks from index 27000 to 27999
# Processed and saved masks from index 28000 to 28999
# Processed and saved masks from index 29000 to 29999
# Processed and saved masks from index 30000 to 30999
# Processed and saved masks from index 31000 to 31999
# Processed and saved masks from index 32000 to 32999
# Processed and saved masks from index 33000 to 33999
# Processed and saved masks from index 34000 to 34999
# Processed and saved masks from index 35000 to 35999
# Processed and saved masks from index 36000 to 36999
# Processed and saved masks from index 37000 to 37999
# Processed and saved masks from index 38000 to 38999
# Processed and saved masks from index 39000 to 39999
# Processed and saved masks from index 40000 to 40999
# Processed and saved masks from index 41000 to 41999
# Processed and saved masks from index 42000 to 42999
# Processed and saved masks from index 43000 to 43999
# Processed and saved masks from index 44000 to 44999
# Processed and saved masks from index 45000 to 45999
# Processed and saved masks from index 46000 to 46999
# Processed and saved masks from index 47000 to 47999
# Processed and saved masks from index 48000 to 48999
# Processed and saved masks from index 49000 to 49999
# Processed and saved masks from index 50000 to 50999
# Processed and saved masks from index 51000 to 51999
# Processed and saved masks from index 52000 to 52999
# Processed and saved masks from index 53000 to 53999
# Processed and saved masks from index 54000 to 54999
# Processed and saved masks from index 55000 to 55999
# Processed and saved masks from index 56000 to 56999
# Processed and saved masks from index 57000 to 57999
# Processed and saved masks from index 58000 to 58999
# Processed and saved masks from index 59000 to 59999
# Processed and saved masks from index 60000 to 60999
# Processed and saved masks from index 61000 to 61999
# Processed and saved masks from index 62000 to 62999
# Processed and saved masks from index 63000 to 63999
# Processed and saved masks from index 64000 to 64999
# Processed and saved masks from index 65000 to 65999
# Processed and saved masks from index 66000 to 66999
# Processed and saved masks from index 67000 to 67999
# Processed and saved masks from index 68000 to 68999
# Processed and saved masks from index 69000 to 69999
# Processed and saved masks from index 70000 to 70999
# Processed and saved masks from index 71000 to 71999
# Processed and saved masks from index 72000 to 72999
# Processed and saved masks from index 73000 to 73999
# Processed and saved masks from index 74000 to 74999
# Processed and saved masks from index 75000 to 75999
# Processed and saved masks from index 76000 to 76999
# Processed and saved masks from index 77000 to 77999
# Processed and saved masks from index 78000 to 78999
# Processed and saved masks from index 79000 to 79999
# Processed and saved masks from index 80000 to 80999
# Processed and saved masks from index 81000 to 81999
# Processed and saved masks from index 82000 to 82999
# Processed and saved masks from index 83000 to 83999
# Processed and saved masks from index 84000 to 84999
# Processed and saved masks from index 85000 to 85999
# Processed and saved masks from index 86000 to 86999
# Processed and saved masks from index 87000 to 87999
# Processed and saved masks from index 88000 to 88999
# Processed and saved masks from index 89000 to 89999
# Processed and saved masks from index 90000 to 90999
# Processed and saved masks from index 91000 to 91999
# Processed and saved masks from index 92000 to 92999
# Processed and saved masks from index 93000 to 93999
# Processed and saved masks from index 94000 to 94999
# Processed and saved masks from index 95000 to 95999
# Processed and saved masks from index 96000 to 96999
# Processed and saved masks from index 97000 to 97999
# Processed and saved masks from index 98000 to 98999
# Processed and saved masks from index 99000 to 99999
# Processed and saved masks from index 100000 to 100999
# Processed and saved masks from index 101000 to 101999
# Processed and saved masks from index 102000 to 102999
# Processed and saved masks from index 103000 to 103999
# Processed and saved masks from index 104000 to 104999
# Processed and saved masks from index 105000 to 105999
# Processed and saved masks from index 106000 to 106999
# Processed and saved masks from index 107000 to 107999
# Processed and saved masks from index 108000 to 108999
# Processed and saved masks from index 109000 to 109999
# Processed and saved masks from index 110000 to 110999
# Processed and saved masks from index 111000 to 111999
# Processed and saved masks from index 112000 to 112999
# Processed and saved masks from index 113000 to 113999
# Processed and saved masks from index 114000 to 114999
# Processed and saved masks from index 115000 to 115999
# Processed and saved masks from index 116000 to 116999
# Processed and saved masks from index 117000 to 117999
# Processed and saved masks from index 118000 to 118999
# Processed and saved masks from index 119000 to 119999
# Processed and saved masks from index 120000 to 120999
# Processed and saved masks from index 121000 to 121999
# Processed and saved masks from index 122000 to 122999
# Processed and saved masks from index 123000 to 123999
# Processed and saved masks from index 124000 to 124999
# Processed and saved masks from index 125000 to 125999
# Processed and saved masks from index 126000 to 126999
# Processed and saved masks from index 127000 to 127999
# Processed and saved masks from index 128000 to 128999
# Processed and saved masks from index 129000 to 129999
# Processed and saved masks from index 130000 to 130999
# Processed and saved masks from index 131000 to 131999
# Processed and saved masks from index 132000 to 132999
# Processed and saved masks from index 133000 to 133999
# Processed and saved masks from index 134000 to 134999
# Processed and saved masks from index 135000 to 135999
# Processed and saved masks from index 136000 to 136999
# Processed and saved masks from index 137000 to 137999
# Processed and saved masks from index 138000 to 138999
# Processed and saved masks from index 139000 to 139999
# Processed and saved masks from index 140000 to 140999
# Processed and saved masks from index 141000 to 141999
# Processed and saved masks from index 142000 to 142999
# Processed and saved masks from index 143000 to 143999
# Processed and saved masks from index 144000 to 144999
# Processed and saved masks from index 145000 to 145999
# Processed and saved masks from index 146000 to 146999
# Processed and saved masks from index 147000 to 147999
# Processed and saved masks from index 148000 to 148999
# Processed and saved masks from index 149000 to 149999
# Processed and saved masks from index 150000 to 150999
# Processed and saved masks from index 151000 to 151999
# Processed and saved masks from index 152000 to 152999
# Processed and saved masks from index 153000 to 153999
# Processed and saved masks from index 154000 to 154999
# Processed and saved masks from index 155000 to 155999
# Processed and saved masks from index 156000 to 156999
# Processed and saved masks from index 157000 to 157999
# Processed and saved masks from index 158000 to 158999
# Processed and saved masks from index 159000 to 159999
# Processed and saved masks from index 160000 to 160999
# Processed and saved masks from index 161000 to 161999
# Processed and saved masks from index 162000 to 162999
# Processed and saved masks from index 163000 to 163999
# Processed and saved masks from index 164000 to 164999
# Processed and saved masks from index 165000 to 165999
# Processed and saved masks from index 166000 to 166999
# Processed and saved masks from index 167000 to 167999
# Processed and saved masks from index 168000 to 168999
# Processed and saved masks from index 169000 to 169999
# Processed and saved masks from index 170000 to 170999
# Processed and saved masks from index 171000 to 171999
# Processed and saved masks from index 172000 to 172999
# Processed and saved masks from index 173000 to 173999
# Processed and saved masks from index 174000 to 174999
# Processed and saved masks from index 175000 to 175999
# Processed and saved masks from index 176000 to 176999
# Processed and saved masks from index 177000 to 177999
# Processed and saved masks from index 178000 to 178999
# Processed and saved masks from index 179000 to 179999
# Processed and saved masks from index 180000 to 180999
# Processed and saved masks from index 181000 to 181999
# Processed and saved masks from index 182000 to 182999
# Processed and saved masks from index 183000 to 183999
# Processed and saved masks from index 184000 to 184999
# Processed and saved masks from index 185000 to 185999
# Processed and saved masks from index 186000 to 186999
# Processed and saved masks from index 187000 to 187999
# Processed and saved masks from index 188000 to 188999
# Processed and saved masks from index 189000 to 189999
# Processed and saved masks from index 190000 to 190999
# Processed and saved masks from index 191000 to 191999
# Processed and saved masks from index 192000 to 192999
# Processed and saved masks from index 193000 to 193999
# Processed and saved masks from index 194000 to 194999
# Processed and saved masks from index 195000 to 195999
# Processed and saved masks from index 196000 to 196999
# Processed and saved masks from index 197000 to 197999
# Processed and saved masks from index 198000 to 198999
# Processed and saved masks from index 199000 to 199999
# Processed and saved masks from index 200000 to 200999
# Processed and saved masks from index 201000 to 201999
# Processed and saved masks from index 202000 to 202999
# Processed and saved masks from index 203000 to 203999
# Processed and saved masks from index 204000 to 204999
# Processed and saved masks from index 205000 to 205999
# Processed and saved masks from index 206000 to 206999
# Processed and saved masks from index 207000 to 207999
# Processed and saved masks from index 208000 to 208999
# Processed and saved masks from index 209000 to 209999
# Processed and saved masks from index 210000 to 210999
# Processed and saved masks from index 211000 to 211999
# Processed and saved masks from index 212000 to 212999
# Processed and saved masks from index 213000 to 213999
# Processed and saved masks from index 214000 to 214999
# Processed and saved masks from index 215000 to 215999
# Processed and saved masks from index 216000 to 216999
# Processed and saved masks from index 217000 to 217999
# Processed and saved masks from index 218000 to 218999
# Processed and saved masks from index 219000 to 219999
# Processed and saved masks from index 220000 to 220999
# Processed and saved masks from index 221000 to 221999
# Processed and saved masks from index 222000 to 222999
# Processed and saved masks from index 223000 to 223999
# Processed and saved masks from index 224000 to 224999
# Processed and saved masks from index 225000 to 225999
# Processed and saved masks from index 226000 to 226999
# Processed and saved masks from index 227000 to 227999
# Processed and saved masks from index 228000 to 228999
# Processed and saved masks from index 229000 to 229999
# Processed and saved masks from index 230000 to 230999
# Processed and saved masks from index 231000 to 231999
# Processed and saved masks from index 232000 to 232999
# Processed and saved masks from index 233000 to 233999
# Processed and saved masks from index 234000 to 234999
# Processed and saved masks from index 235000 to 235999
# Processed and saved masks from index 236000 to 236999
# Processed and saved masks from index 237000 to 237999
# Processed and saved masks from index 238000 to 238999
# Processed and saved masks from index 239000 to 239999
# Processed and saved masks from index 240000 to 240999
# Processed and saved masks from index 241000 to 241999
# Processed and saved masks from index 242000 to 242999
# Processed and saved masks from index 243000 to 243999
# Processed and saved masks from index 244000 to 244999
# Processed and saved masks from index 245000 to 245999
# Processed and saved masks from index 246000 to 246999
# Processed and saved masks from index 247000 to 247999
# Processed and saved masks from index 248000 to 248999
# Processed and saved masks from index 249000 to 249999
# Processed and saved masks from index 250000 to 250999
# Processed and saved masks from index 251000 to 251999
# Processed and saved masks from index 252000 to 252999
# Processed and saved masks from index 253000 to 253999
# Processed and saved masks from index 254000 to 254999
# Processed and saved masks from index 255000 to 255999
# Processed and saved masks from index 256000 to 256999
# Processed and saved masks from index 257000 to 257999
# Processed and saved masks from index 258000 to 258999
# Processed and saved masks from index 259000 to 259999
# Processed and saved masks from index 260000 to 260999
# Processed and saved masks from index 261000 to 261999
# Processed and saved masks from index 262000 to 262999
# Processed and saved masks from index 263000 to 263999
# Processed and saved masks from index 264000 to 264999
# Processed and saved masks from index 265000 to 265999
# Processed and saved masks from index 266000 to 266999
# Processed and saved masks from index 267000 to 267999
# Processed and saved masks from index 268000 to 268999
# Processed and saved masks from index 269000 to 269999
# Processed and saved masks from index 270000 to 270999
# Processed and saved masks from index 271000 to 271999
# Processed and saved masks from index 272000 to 272999
# Processed and saved masks from index 273000 to 273999
# Processed and saved masks from index 274000 to 274999
# Processed and saved masks from index 275000 to 275999
# Processed and saved masks from index 276000 to 276999
# Processed and saved masks from index 277000 to 277999
# Processed and saved masks from index 278000 to 278999
# Processed and saved masks from index 279000 to 279999
# Processed and saved masks from index 280000 to 280999
# Processed and saved masks from index 281000 to 281999
# Processed and saved masks from index 282000 to 282999
# Processed and saved masks from index 283000 to 283999
# Processed and saved masks from index 284000 to 284999
# Processed and saved masks from index 285000 to 285999
# Processed and saved masks from index 286000 to 286999
# Processed and saved masks from index 287000 to 287999
# Processed and saved masks from index 288000 to 288999
# Processed and saved masks from index 289000 to 289999
# Processed and saved masks from index 290000 to 290999
# Processed and saved masks from index 291000 to 291999
# Processed and saved masks from index 292000 to 292999
# Processed and saved masks from index 293000 to 293999
# Processed and saved masks from index 294000 to 294999
# Processed and saved masks from index 295000 to 295999
# Processed and saved masks from index 296000 to 296999
# Processed and saved masks from index 297000 to 297999
# Processed and saved masks from index 298000 to 298999
# Processed and saved masks from index 299000 to 299999
# Processed and saved masks from index 300000 to 300999
# Processed and saved masks from index 301000 to 301999
# Processed and saved masks from index 302000 to 302999
# Processed and saved masks from index 303000 to 303999
# Processed and saved masks from index 304000 to 304999
# Processed and saved masks from index 305000 to 305999
# Processed and saved masks from index 306000 to 306999
# Processed and saved masks from index 307000 to 307999
# Processed and saved masks from index 308000 to 308999
# Processed and saved masks from index 309000 to 309999
# Processed and saved masks from index 310000 to 310999
# Processed and saved masks from index 311000 to 311999
# Processed and saved masks from index 312000 to 312999
# Processed and saved masks from index 313000 to 313999
# Processed and saved masks from index 314000 to 314999
# Processed and saved masks from index 315000 to 315999
# Processed and saved masks from index 316000 to 316999
# Processed and saved masks from index 317000 to 317999
# Processed and saved masks from index 318000 to 318999
# Processed and saved masks from index 319000 to 319999
# Processed and saved masks from index 320000 to 320999
# Processed and saved masks from index 321000 to 321999
# Processed and saved masks from index 322000 to 322999
# Processed and saved masks from index 323000 to 323999
# Processed and saved masks from index 324000 to 324999
# Processed and saved masks from index 325000 to 325999
# Processed and saved masks from index 326000 to 326999
# Processed and saved masks from index 327000 to 327999
# Processed and saved masks from index 328000 to 328999
# Processed and saved masks from index 329000 to 329999
# Processed and saved masks from index 330000 to 330999
# Processed and saved masks from index 331000 to 331999
# Processed and saved masks from index 332000 to 332999
# Processed and saved masks from index 333000 to 333999
# Processed and saved masks from index 334000 to 334999
# Processed and saved masks from index 335000 to 335999
# Processed and saved masks from index 336000 to 336999
# Processed and saved masks from index 337000 to 337999
# Processed and saved masks from index 338000 to 338999
# Processed and saved masks from index 339000 to 339999
# Processed and saved masks from index 340000 to 340999
# Processed and saved masks from index 341000 to 341999
# Processed and saved masks from index 342000 to 342999
# Processed and saved masks from index 343000 to 343999
# Processed and saved masks from index 344000 to 344999
# Processed and saved masks from index 345000 to 345999
# Processed and saved masks from index 346000 to 346999
# Processed and saved masks from index 347000 to 347999
# Processed and saved masks from index 348000 to 348999
# Processed and saved masks from index 349000 to 349999
# Processed and saved masks from index 350000 to 350999
# Processed and saved masks from index 351000 to 351999
# Processed and saved masks from index 352000 to 352999
# Processed and saved masks from index 353000 to 353999
# Processed and saved masks from index 354000 to 354999
# Processed and saved masks from index 355000 to 355999
# Processed and saved masks from index 356000 to 356999
# Processed and saved masks from index 357000 to 357999
# Processed and saved masks from index 358000 to 358999
# Processed and saved masks from index 359000 to 359999
# Processed and saved masks from index 360000 to 360999
# Processed and saved masks from index 361000 to 361999
# Processed and saved masks from index 362000 to 362999
# Processed and saved masks from index 363000 to 363999
# Processed and saved masks from index 364000 to 364999
# Processed and saved masks from index 365000 to 365999
# Processed and saved masks from index 366000 to 366999
# Processed and saved masks from index 367000 to 367999
# Processed and saved masks from index 368000 to 368999
# Processed and saved masks from index 369000 to 369999
# Processed and saved masks from index 370000 to 370999
# Processed and saved masks from index 371000 to 371999
# Processed and saved masks from index 372000 to 372999
# Processed and saved masks from index 373000 to 373999
# Processed and saved masks from index 374000 to 374999
# Processed and saved masks from index 375000 to 375999
# Processed and saved masks from index 376000 to 376999
# Processed and saved masks from index 377000 to 377999
# Processed and saved masks from index 378000 to 378999
# Processed and saved masks from index 379000 to 379999
# Processed and saved masks from index 380000 to 380999
# Processed and saved masks from index 381000 to 381999
# Processed and saved masks from index 382000 to 382999
# Processed and saved masks from index 383000 to 383999
# Processed and saved masks from index 384000 to 384999
# Processed and saved masks from index 385000 to 385999
# Processed and saved masks from index 386000 to 386999
# Processed and saved masks from index 387000 to 387999
# Processed and saved masks from index 388000 to 388999
# Processed and saved masks from index 389000 to 389999
# Processed and saved masks from index 390000 to 390999
# Processed and saved masks from index 391000 to 391999
# Processed and saved masks from index 392000 to 392999
# Processed and saved masks from index 393000 to 393999
# Processed and saved masks from index 394000 to 394999
# Processed and saved masks from index 395000 to 395999
# Processed and saved masks from index 396000 to 396999
# Processed and saved masks from index 397000 to 397999
# Processed and saved masks from index 398000 to 398999
# Processed and saved masks from index 399000 to 399999
# Processed and saved masks from index 400000 to 400999
# Processed and saved masks from index 401000 to 401999
# Processed and saved masks from index 402000 to 402999
# Processed and saved masks from index 403000 to 403999
# Processed and saved masks from index 404000 to 404999
# Processed and saved masks from index 405000 to 405999
# Processed and saved masks from index 406000 to 406999
# Processed and saved masks from index 407000 to 407999
# Processed and saved masks from index 408000 to 408999
# Processed and saved masks from index 409000 to 409999
# Processed and saved masks from index 410000 to 410999
# Processed and saved masks from index 411000 to 411999
# Processed and saved masks from index 412000 to 412999
# Processed and saved masks from index 413000 to 413999
# Processed and saved masks from index 414000 to 414999
# Processed and saved masks from index 415000 to 415999
# Processed and saved masks from index 416000 to 416999
# Processed and saved masks from index 417000 to 417999
# Processed and saved masks from index 418000 to 418999
# Processed and saved masks from index 419000 to 419999
# Processed and saved masks from index 420000 to 420999
# Processed and saved masks from index 421000 to 421999
# Processed and saved masks from index 422000 to 422999
# Processed and saved masks from index 423000 to 423999
# Processed and saved masks from index 424000 to 424999
# Processed and saved masks from index 425000 to 425999
# Processed and saved masks from index 426000 to 426999
# Processed and saved masks from index 427000 to 427999
# Processed and saved masks from index 428000 to 428999
# Processed and saved masks from index 429000 to 429999
# Processed and saved masks from index 430000 to 430999
# Processed and saved masks from index 431000 to 431999
# Processed and saved masks from index 432000 to 432999
# Processed and saved masks from index 433000 to 433999
# Processed and saved masks from index 434000 to 434999
# Processed and saved masks from index 435000 to 435999
# Processed and saved masks from index 436000 to 436999
# Processed and saved masks from index 437000 to 437999
# Processed and saved masks from index 438000 to 438999
# Processed and saved masks from index 439000 to 439999
# Processed and saved masks from index 440000 to 440999
# Processed and saved masks from index 441000 to 441999
# Processed and saved masks from index 442000 to 442999
# Processed and saved masks from index 443000 to 443999
# Processed and saved masks from index 444000 to 444999
# Processed and saved masks from index 445000 to 445999
# Processed and saved masks from index 446000 to 446999
# Processed and saved masks from index 447000 to 447999
# Processed and saved masks from index 448000 to 448999
# Processed and saved masks from index 449000 to 449999
# Processed and saved masks from index 450000 to 450999
# Processed and saved masks from index 451000 to 451999
# Processed and saved masks from index 452000 to 452999
# Processed and saved masks from index 453000 to 453999
# Processed and saved masks from index 454000 to 454999
# Processed and saved masks from index 455000 to 455999
# Processed and saved masks from index 456000 to 456999
# Processed and saved masks from index 457000 to 457999
# Processed and saved masks from index 458000 to 458999
# Processed and saved masks from index 459000 to 459999
# Processed and saved masks from index 460000 to 460999
# Processed and saved masks from index 461000 to 461999
# Processed and saved masks from index 462000 to 462999
# Processed and saved masks from index 463000 to 463999
# Processed and saved masks from index 464000 to 464999
# Processed and saved masks from index 465000 to 465999
# Processed and saved masks from index 466000 to 466999
# Processed and saved masks from index 467000 to 467999
# Processed and saved masks from index 468000 to 468999
# Processed and saved masks from index 469000 to 469999
# Processed and saved masks from index 470000 to 470999
# Processed and saved masks from index 471000 to 471999
# Processed and saved masks from index 472000 to 472999
# Processed and saved masks from index 473000 to 473999
# Processed and saved masks from index 474000 to 474999
# Processed and saved masks from index 475000 to 475999
# Processed and saved masks from index 476000 to 476999
# Processed and saved masks from index 477000 to 477999
# Processed and saved masks from index 478000 to 478999
# Processed and saved masks from index 479000 to 479999
# Processed and saved masks from index 480000 to 480999
# Processed and saved masks from index 481000 to 481999
# Processed and saved masks from index 482000 to 482999
# Processed and saved masks from index 483000 to 483999
# Processed and saved masks from index 484000 to 484999
# Processed and saved masks from index 485000 to 485999
# Processed and saved masks from index 486000 to 486999
# Processed and saved masks from index 487000 to 487999
# Processed and saved masks from index 488000 to 488999
# Processed and saved masks from index 489000 to 489999
# Processed and saved masks from index 490000 to 490999
# Processed and saved masks from index 491000 to 491999
# Processed and saved masks from index 492000 to 492999
# Processed and saved masks from index 493000 to 493439
# Resized masks saved to ../data/training_data/train/AnnualCrop_train_masks_cleaned_resized.npy

# %%
resized_masks = np.load(output_resized_masks, mmap_mode="r")
print(f"Resized masks shape: {resized_masks.shape}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 resized_masks = np.load(output_resized_masks, mmap_mode="r")
#       2 print(f"Resized masks shape: {resized_masks.shape}")
#
# File ~/anaconda3/envs/cas_deepL/lib/python3.10/site-packages/numpy/lib/npyio.py:462, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     459 else:
#     460     # Try a pickle
#     461     if not allow_pickle:
# --> 462         raise ValueError("Cannot load file containing pickled data "
#     463                          "when allow_pickle=False")
#     464     try:
#     465         return pickle.load(fid, **pickle_kwargs)
#
# ValueError: Cannot load file containing pickled data when allow_pickle=False
